# %%
PATH = "/tmp/f1d4c373-990b-4fc7-bf43-2c51c87ea91a"

# %% [markdown]
# # Parse pandas

# %%
df = pd.read_json(PATH, orient="record")
df = df["data"].map(lambda x: dict(x))
df = pd.json_normalize(df)
df.head()
# Out:
#                              Event.#attributes.xmlns  \
# 0  http://schemas.microsoft.com/win/2004/08/event...
# 1  http://schemas.microsoft.com/win/2004/08/event...
# 2  http://schemas.microsoft.com/win/2004/08/event...
# 3  http://schemas.microsoft.com/win/2004/08/event...
# 4  http://schemas.microsoft.com/win/2004/08/event...
#
#                    Event.EventData.CommandLine Event.EventData.Company  \
# 0  "C:\Users\IEUser\Downloads\com-hijack.exe"                        ?
# 1                                          NaN                     NaN
# 2                                          NaN                     NaN
# 3                                          NaN                     NaN
# 4      C:\Windows\system32\cmd.exe /c test.bat   Microsoft Corporation
#
#   Event.EventData.CurrentDirectory Event.EventData.Description  \
# 0       C:\Users\IEUser\Downloads\                           ?
# 1                              NaN                         NaN
# 2                              NaN                         NaN
# 3                              NaN                         NaN
# 4       C:\Users\IEUser\Downloads\   Windows Command Processor
#
#                 Event.EventData.FileVersion  \
# 0                                         ?
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4  6.1.7601.17514 (win7sp1_rtm.101119-1850)
#
#                               Event.EventData.Hashes  \
# 0  SHA1=6F598827EFE472BC8D98CD173AD49B35B041000C,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  SHA1=EE8CBF12D87C4D388F09B4F69BED2E91682920B5,...
#
#                       Event.EventData.Image Event.EventData.IntegrityLevel  \
# 0  C:\Users\IEUser\Downloads\com-hijack.exe                           High
# 1  C:\Users\IEUser\Downloads\com-hijack.exe                            NaN
# 2  C:\Users\IEUser\Downloads\com-hijack.exe                            NaN
# 3  C:\Users\IEUser\Downloads\com-hijack.exe                            NaN
# 4               C:\Windows\System32\cmd.exe                           High
#
#               Event.EventData.LogonGuid  ...  \
# 0  365ABB72-39CC-5CE3-0000-002096C70000  ...
# 1                                   NaN  ...
# 2                                   NaN  ...
# 3                                   NaN  ...
# 4  365ABB72-39CC-5CE3-0000-002096C70000  ...
#
#   Event.EventData.SourceProcessGUID Event.EventData.SourceProcessId  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#   Event.EventData.SourceThreadId Event.EventData.TargetImage  \
# 0                            NaN                         NaN
# 1                            NaN                         NaN
# 2                            NaN                         NaN
# 3                            NaN                         NaN
# 4                            NaN                         NaN
#
#    Event.EventData.TargetProcessGUID Event.EventData.TargetProcessId  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
#
#    Event.EventData.ImageLoaded Event.EventData.Signature  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
#
#   Event.EventData.SignatureStatus  Event.EventData.Signed
# 0                             NaN                     NaN
# 1                             NaN                     NaN
# 2                             NaN                     NaN
# 3                             NaN                     NaN
# 4                             NaN                     NaN
#
# [5 rows x 56 columns]

# %% [markdown]
# # Parse DASK

# %%
meta_dtypes = {
                                 'Event.EventData.CommandLine': 'object',
                                 'Event.System.Keywords': 'object',
                                 'Event.System.TimeCreated.#attributes.SystemTime': 'object',
                                 'Event.System.Version': 'object',
                                 'Event.EventData.LogonGuid': 'object',
                                 'Event.EventData.Product': 'object',
                                 'Event.#attributes.xmlns': 'object',
                                 'Event.EventData.ImageLoaded': 'object',
                                 'Event.System.Security.#attributes.UserID': 'object',
                                 'Event.EventData.IntegrityLevel': 'object',
                                 'Event.System.Provider.#attributes.Name': 'object',
                                 'Event.EventData.User': 'object',
                                 'Event.EventData.Description': 'object',
                                 'Event.System.Channel': 'object',
                                 'Event.EventData.CurrentDirectory': 'object',
                                 'Event.EventData.TargetProcessId': 'object',
                                 # 'event_record_id': 'object',
                                 'Event.EventData.ParentProcessGuid': 'object',
                                 'Event.System.Correlation': 'object',
                                 'Event.EventData.TargetObject': 'object',
                                 'Event.EventData.EventType': 'float64',
                                 'Event.EventData.CallTrace': 'float64',
                                 'Event.EventData.GrantedAccess': 'float64',
                                 'Event.System.Task': 'object',
                                 'Event.EventData.Image': 'object',
                                 'Event.EventData.RuleName': 'object',
                                 'Event.EventData.TerminalSessionId': 'object',
                                 'Event.EventData.SourceThreadId': 'object',
                                 'Event.System.EventID': 'object',
                                 'Event.EventData.UtcTime': 'object',
                                 'Event.System.Computer': 'object',
                                 'Event.EventData.Signature': 'object',
                                 'Event.EventData.SourceProcessId': 'object',
                                 'Event.EventData.ProcessGuid': 'object',
                                 'Event.System.Execution.#attributes.ProcessID': 'object',
                                 'Event.EventData.ParentCommandLine': 'object',
                                 'Event.EventData.Signed': 'object',
                                 'Event.EventData.LogonId': 'object',
                                 'Event.EventData.ProcessId': 'object',
                                 'Event.EventData.ParentImage': 'object',
                                 'Event.EventData.SignatureStatus': 'object',
                                 'Event.EventData.SourceImage': 'object',
                                 # 'timestamp': 'object',
                                 'Event.EventData.FileVersion': 'object',
                                 'Event.System.Opcode': 'object',
                                 'Event.System.Execution.#attributes.ThreadID': 'object',
                                 'Event.System.Level': 'object',
                                 'Event.EventData.TargetImage': 'object',
                                 'Event.EventData.TargetProcessGUID': 'object',
                                 'Event.EventData.Company': 'object',
                                 'Event.EventData.TargetFilename': 'object',
                                 'Event.EventData.SourceProcessGUID': 'object',
                                 'Event.EventData.ParentProcessId': 'object',
                                 'Event.System.EventRecordID': 'object',
                                 'Event.System.Provider.#attributes.Guid': 'object',
                                 'Event.EventData.Details': 'float64',
                                 'Event.EventData.CreationUtcTime': 'float64',
                                 'Event.EventData.Hashes': 'object'
                             }

dask_df = dd.read_json(PATH, orient="record", encoding="utf-8")
data = dask_df["data"].apply(lambda x: dict(x), meta=dict)

def normalize(x, columns_order=list(meta_dtypes.keys())):
    df = pd.json_normalize(x)
    return df.loc[:, columns_order]
    
data = data.map_partitions(normalize, meta=meta_dtypes)

data['event_record_id'] = dask_df["Record"]
data.compute()
# Out:
#                           Event.EventData.CommandLine Event.System.Keywords  \
# 0         "C:\Users\IEUser\Downloads\com-hijack.exe"     0x8000000000000000
# 1                                                 NaN    0x8000000000000000
# 2                                                 NaN    0x8000000000000000
# 3                                                 NaN    0x8000000000000000
# 4             C:\Windows\system32\cmd.exe /c test.bat    0x8000000000000000
# 5                                                 NaN    0x8000000000000000
# 6                C:\Windows\system32\cmd.exe /c pause    0x8000000000000000
# 7                                                 NaN    0x8000000000000000
# 8      "C:\Program Files\Mozilla Firefox\firefox.exe"    0x8000000000000000
# 9   "C:\Program Files\Mozilla Firefox\firefox.exe"...    0x8000000000000000
# 10                                                NaN    0x8000000000000000
# 11                    "C:\Windows\System32\calc.exe"     0x8000000000000000
# 12                                                NaN    0x8000000000000000
# 13                    "C:\Windows\System32\calc.exe"     0x8000000000000000
# 14  "C:\Program Files\Mozilla Firefox\firefox.exe"...    0x8000000000000000
# 15  "C:\Program Files\Mozilla Firefox\firefox.exe"...    0x8000000000000000
# 16  "C:\Program Files\Mozilla Firefox\firefox.exe"...    0x8000000000000000
# 17                                                NaN    0x8000000000000000
# 18                                                NaN    0x8000000000000000
#
#    Event.System.TimeCreated.#attributes.SystemTime  Event.System.Version  \
# 0                      2019-05-21T00:35:07.308923Z                     5
# 1                      2019-05-21T00:35:07.463144Z                     2
# 2                      2019-05-21T00:35:07.474160Z                     2
# 3                      2019-05-21T00:35:07.474160Z                     2
# 4                      2019-05-21T00:35:07.474160Z                     5
# 5                      2019-05-21T00:35:07.474160Z                     3
# 6                      2019-05-21T00:35:07.474160Z                     5
# 7                      2019-05-21T00:35:07.474160Z                     3
# 8                      2019-05-21T00:35:07.518223Z                     5
# 9                      2019-05-21T00:35:07.870729Z                     5
# 10                     2019-05-21T00:35:08.224338Z                     3
# 11                     2019-05-21T00:35:08.279417Z                     5
# 12                     2019-05-21T00:35:08.717041Z                     3
# 13                     2019-05-21T00:35:08.728057Z                     5
# 14                     2019-05-21T00:35:08.728057Z                     5
# 15                     2019-05-21T00:35:10.161517Z                     5
# 16                     2019-05-21T00:35:12.705165Z                     5
# 17                     2019-05-21T00:36:14.747769Z                     2
# 18                     2019-05-21T00:36:14.747769Z                     2
#
#                Event.EventData.LogonGuid  \
# 0   365ABB72-39CC-5CE3-0000-002096C70000
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4   365ABB72-39CC-5CE3-0000-002096C70000
# 5                                    NaN
# 6   365ABB72-39CC-5CE3-0000-002096C70000
# 7                                    NaN
# 8   365ABB72-39CC-5CE3-0000-002096C70000
# 9   365ABB72-39CC-5CE3-0000-002096C70000
# 10                                   NaN
# 11  365ABB72-39CC-5CE3-0000-002096C70000
# 12                                   NaN
# 13  365ABB72-39CC-5CE3-0000-002096C70000
# 14  365ABB72-39CC-5CE3-0000-002096C70000
# 15  365ABB72-39CC-5CE3-0000-002096C70000
# 16  365ABB72-39CC-5CE3-0000-002096C70000
# 17                                   NaN
# 18                                   NaN
#
#                  Event.EventData.Product  \
# 0                                      ?
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4   Microsoft® Windows® Operating System
# 5                                    NaN
# 6   Microsoft® Windows® Operating System
# 7                                    NaN
# 8                                Firefox
# 9                                Firefox
# 10                                     ?
# 11  Microsoft® Windows® Operating System
# 12                                     ?
# 13  Microsoft® Windows® Operating System
# 14                               Firefox
# 15                               Firefox
# 16                               Firefox
# 17                                   NaN
# 18                                   NaN
#
#                               Event.#attributes.xmlns  \
# 0   http://schemas.microsoft.com/win/2004/08/event...
# 1   http://schemas.microsoft.com/win/2004/08/event...
# 2   http://schemas.microsoft.com/win/2004/08/event...
# 3   http://schemas.microsoft.com/win/2004/08/event...
# 4   http://schemas.microsoft.com/win/2004/08/event...
# 5   http://schemas.microsoft.com/win/2004/08/event...
# 6   http://schemas.microsoft.com/win/2004/08/event...
# 7   http://schemas.microsoft.com/win/2004/08/event...
# 8   http://schemas.microsoft.com/win/2004/08/event...
# 9   http://schemas.microsoft.com/win/2004/08/event...
# 10  http://schemas.microsoft.com/win/2004/08/event...
# 11  http://schemas.microsoft.com/win/2004/08/event...
# 12  http://schemas.microsoft.com/win/2004/08/event...
# 13  http://schemas.microsoft.com/win/2004/08/event...
# 14  http://schemas.microsoft.com/win/2004/08/event...
# 15  http://schemas.microsoft.com/win/2004/08/event...
# 16  http://schemas.microsoft.com/win/2004/08/event...
# 17  http://schemas.microsoft.com/win/2004/08/event...
# 18  http://schemas.microsoft.com/win/2004/08/event...
#
#    Event.EventData.ImageLoaded Event.System.Security.#attributes.UserID  \
# 0                          NaN                                 S-1-5-18
# 1                          NaN                                 S-1-5-18
# 2                          NaN                                 S-1-5-18
# 3                          NaN                                 S-1-5-18
# 4                          NaN                                 S-1-5-18
# 5                          NaN                                 S-1-5-18
# 6                          NaN                                 S-1-5-18
# 7                          NaN                                 S-1-5-18
# 8                          NaN                                 S-1-5-18
# 9                          NaN                                 S-1-5-18
# 10     C:\ProgramData\demo.dll                                 S-1-5-18
# 11                         NaN                                 S-1-5-18
# 12     C:\ProgramData\demo.dll                                 S-1-5-18
# 13                         NaN                                 S-1-5-18
# 14                         NaN                                 S-1-5-18
# 15                         NaN                                 S-1-5-18
# 16                         NaN                                 S-1-5-18
# 17                         NaN                                 S-1-5-18
# 18                         NaN                                 S-1-5-18
#
#    Event.EventData.IntegrityLevel  ... Event.EventData.Company  \
# 0                            High  ...                       ?
# 1                             NaN  ...                     NaN
# 2                             NaN  ...                     NaN
# 3                             NaN  ...                     NaN
# 4                            High  ...   Microsoft Corporation
# 5                             NaN  ...                     NaN
# 6                            High  ...   Microsoft Corporation
# 7                             NaN  ...                     NaN
# 8                            High  ...     Mozilla Corporation
# 9                            High  ...     Mozilla Corporation
# 10                            NaN  ...                       ?
# 11                           High  ...   Microsoft Corporation
# 12                            NaN  ...                       ?
# 13                           High  ...   Microsoft Corporation
# 14                            Low  ...     Mozilla Corporation
# 15                            Low  ...     Mozilla Corporation
# 16                            Low  ...     Mozilla Corporation
# 17                            NaN  ...                     NaN
# 18                            NaN  ...                     NaN
#
#         Event.EventData.TargetFilename     Event.EventData.SourceProcessGUID  \
# 0                                  NaN                                   NaN
# 1              C:\ProgramData\demo.dll                                   NaN
# 2                                  NaN                                   NaN
# 3   C:\Users\IEUser\Downloads\test.bat                                   NaN
# 4                                  NaN                                   NaN
# 5                                  NaN  365ABB72-47BB-5CE3-0000-0010BFA83E00
# 6                                  NaN                                   NaN
# 7                                  NaN  365ABB72-47BB-5CE3-0000-0010BFA83E00
# 8                                  NaN                                   NaN
# 9                                  NaN                                   NaN
# 10                                 NaN                                   NaN
# 11                                 NaN                                   NaN
# 12                                 NaN                                   NaN
# 13                                 NaN                                   NaN
# 14                                 NaN                                   NaN
# 15                                 NaN                                   NaN
# 16                                 NaN                                   NaN
# 17                                 NaN                                   NaN
# 18                                 NaN                                   NaN
#
#    Event.EventData.ParentProcessId Event.System.EventRecordID  \
# 0                           1376.0                        370
# 1                              NaN                        371
# 2                              NaN                        372
# 3                              NaN                        373
# 4                           1912.0                        374
# 5                              NaN                        375
# 6                           1912.0                        376
# 7                              NaN                        377
# 8                           3944.0                        378
# 9                           3168.0                        379
# 10                             NaN                        380
# 11                          3168.0                        381
# 12                             NaN                        382
# 13                          3168.0                        383
# 14                          3168.0                        384
# 15                          3168.0                        385
# 16                          3168.0                        386
# 17                             NaN                        387
# 18                             NaN                        388
#
#     Event.System.Provider.#attributes.Guid  Event.EventData.Details  \
# 0     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 1     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 2     5770385F-C22A-43E0-BF4C-06F5698FFBD9  C:\ProgramData\demo.dll
# 3     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 4     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 5     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 6     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 7     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 8     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 9     5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 10    5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 11    5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 12    5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 13    5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 14    5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 15    5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 16    5770385F-C22A-43E0-BF4C-06F5698FFBD9                      NaN
# 17    5770385F-C22A-43E0-BF4C-06F5698FFBD9       DWORD (0x00000001)
# 18    5770385F-C22A-43E0-BF4C-06F5698FFBD9       DWORD (0x00000000)
#
#    Event.EventData.CreationUtcTime  \
# 0                              NaN
# 1          2019-05-20 23:39:21.672
# 2                              NaN
# 3          2019-05-20 23:39:21.672
# 4                              NaN
# 5                              NaN
# 6                              NaN
# 7                              NaN
# 8                              NaN
# 9                              NaN
# 10                             NaN
# 11                             NaN
# 12                             NaN
# 13                             NaN
# 14                             NaN
# 15                             NaN
# 16                             NaN
# 17                             NaN
# 18                             NaN
#
#                                Event.EventData.Hashes event_record_id
# 0   SHA1=6F598827EFE472BC8D98CD173AD49B35B041000C,...               1
# 1                                                 NaN               2
# 2                                                 NaN               3
# 3                                                 NaN               4
# 4   SHA1=EE8CBF12D87C4D388F09B4F69BED2E91682920B5,...               5
# 5                                                 NaN               6
# 6   SHA1=EE8CBF12D87C4D388F09B4F69BED2E91682920B5,...               7
# 7                                                 NaN               8
# 8   SHA1=B18D536DA2242D6D9BB66CBE63CF312ABC9987A8,...               9
# 9   SHA1=B18D536DA2242D6D9BB66CBE63CF312ABC9987A8,...              10
# 10  SHA1=263AF863339D5F077CC419F7022B768644E8C3C6,...              11
# 11  SHA1=9018A7D6CDBE859A430E8794E73381F77C840BE0,...              12
# 12  SHA1=263AF863339D5F077CC419F7022B768644E8C3C6,...              13
# 13  SHA1=9018A7D6CDBE859A430E8794E73381F77C840BE0,...              14
# 14  SHA1=B18D536DA2242D6D9BB66CBE63CF312ABC9987A8,...              15
# 15  SHA1=B18D536DA2242D6D9BB66CBE63CF312ABC9987A8,...              16
# 16  SHA1=B18D536DA2242D6D9BB66CBE63CF312ABC9987A8,...              17
# 17                                                NaN              18
# 18                                                NaN              19
#
# [19 rows x 57 columns]

# %%
dask_df
# Out:
# Dask DataFrame Structure:
#               Record    data
# npartitions=1
#                int64  object
#                  ...     ...
# Dask Name: from-delayed, 2 tasks
